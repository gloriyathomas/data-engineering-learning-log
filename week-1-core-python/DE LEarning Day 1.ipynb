# %%
# Day 1: Basic Python syntax
print("Hello, Data Engineering!")

# Variables and Data Types
x = 42
y = "Data Pipeline"
print(x, y)

# Lists and Loops
data = [1, 2, 3, 4]
for item in data:
    print(item)
# Out:
# Hello, Data Engineering!
# 42 Data Pipeline
# 1
# 2
# 3
# 4
